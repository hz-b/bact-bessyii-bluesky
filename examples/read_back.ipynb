# %%
from databroker import catalog

db = catalog["heavy"]
uid = '3c256552-7c81-4a1f-bf92-bfec5587cd3a'
run = db[uid]
dataX = run.primary.read()

# %%
help(run.primary)
# Out:
# Help on BlueskyEventStream in module databroker.core object:
#
# class BlueskyEventStream(databroker.intake_xarray_core.base.DataSourceMixin)
#  |  BlueskyEventStream(stream_name, get_run_stop, get_event_descriptors, get_event_pages, get_event_count, get_resources, get_resource, lookup_resource_for_datum, get_datum_pages, fillers, transforms, metadata, entry, include=None, exclude=None, sub_dict='data', configuration_for=None, **kwargs)
#  |
#  |  Catalog representing one Event Stream from one Run.
#  |
#  |  Parameters
#  |  ----------
#  |  stream_name : string
#  |      Stream name, such as 'primary'.
#  |  get_run_stop : callable
#  |      Expected signature ``get_run_stop() -> RunStop``
#  |  get_event_descriptors : callable
#  |      Expected signature ``get_event_descriptors() -> List[EventDescriptors]``
#  |  get_event_pages : callable
#  |      Expected signature ``get_event_pages(descriptor_uid) -> generator``
#  |      where ``generator`` yields event_page documents
# ...

# %%
run.primary.get_persisted()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 run.primary.get_persisted()
#
# File ~/workspace/bact/venv/lib/python3.10/site-packages/databroker/core.py:1223, in BlueskyEventStream.get_persisted(self)
#    1222 def get_persisted(self):
# -> 1223     raise KeyError("Does not support intake persistence")
#
# KeyError: 'Does not support intake persistence'

# %%
for ev in run.primary.get_events():
    print(ev)
    break
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 for ev in run.primary.get_events():
#       2     print(ev)
#       3     break
#
# AttributeError: 'BlueskyEventStream' object has no attribute 'get_events'

# %%
run.primary
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/workspace/bact/venv/lib/python3.10/site-packages/IPython/core/formatters.py:920, in IPythonDisplayFormatter.__call__(self, obj)
#     918 method = get_real_method(obj, self.print_method)
#     919 if method is not None:
# --> 920     method()
#     921     return True
#
# File ~/workspace/bact/venv/lib/python3.10/site-packages/intake/source/base.py:271, in DataSourceBase._ipython_display_(self)
#     269 from IPython.display import display
#     270 data = self._yaml()['sources']
# --> 271 contents = dump(data, default_flow_style=False)
#     272 display({
#     273     'application/yaml': contents,
#     274     'text/plain': pretty_describe(contents)
#     275 }, metadata={
#     276     'application/json': {'root': self.name}
#     277 }, raw=True)
#
# ...
